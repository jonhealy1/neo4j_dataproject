# %% [markdown]
# #### Load data then sort it by source and target subreddits

# %%
import pandas as pd
data = pd.read_csv("title_tab_separated.csv")
data.head()

data_sorted = data.sort_values(by=['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT'], inplace=False, ascending=False)
data_sorted.head()

# %% [markdown]
# #### Make positive and negative sentiment dataframes

# %%
neg_matrix = data_sorted['LINK_SENTIMENT'] < 0
pos_matrix = data_sorted['LINK_SENTIMENT'] > 0
data_sorted[neg_matrix]
data_sorted[pos_matrix]

matrix1_neg = data_sorted[neg_matrix].groupby(['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']).LINK_SENTIMENT.sum()
matrix1_pos = data_sorted[pos_matrix].groupby(['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']).LINK_SENTIMENT.sum()

# %% [markdown]
# #### the_donald -> target # of link sentiments positive

# %%
print(matrix1_pos['the_donald'].to_string())

# %% [markdown]
# #### the_donald -> target # of link sentiments negative

# %%
print(matrix1_neg['the_donald'].to_string())

# %% [markdown]
# #### Make dataframe for total sentiment: positive plus sentiment

# %%
matrix_total = data_sorted.groupby(['SOURCE_SUBREDDIT', 'TARGET_SUBREDDIT']).LINK_SENTIMENT.sum()

# %% [markdown]
# #### the_donald -> target # of link sentiments total - negative + postive

# %%
print(matrix_total['the_donald'].to_string())

# %% [markdown]
# #### Save positive and negatives CSVs

# %%
matrix1_pos.to_csv('matrix1_pos.csv')
matrix1_neg.to_csv('matrix1_neg.csv')

# %% [markdown]
# #### Load neg CSV that was just saved

# %%
neg_data = pd.read_csv("matrix1_neg.csv")
neg_data.head()

pos_data = pd.read_csv("matrix1_pos.csv")
pos_data.head()

# %%
print(neg_data.columns)
print(pos_data.columns)

# %%
neg_data.rename(columns={'1200isjerky':'source',
                          '1200isplenty':'target',
                          '-1':'weight'}, 
                 inplace=True)

pos_data.rename(columns={'07thexpansion':'source',
                          'visualnovels':'target',
                          '1':'weight'}, 
                 inplace=True)

# %%
pos_data.to_csv('matrix1_pos.csv')
neg_data.to_csv('matrix1_neg.csv')

# %% [markdown]
# #### display graph - jgraph

# %%
import jgraph
from py2neo import Graph, Node, Relationship
import sys
graph = Graph(password="password")

# %%
data = graph.run("MATCH (s:Subreddit)-[l:LINK]->(t:Subreddit) \
        WHERE l.weight < -40 \
        RETURN s.id, t.id LIMIT 20")
data = [tuple(x) for x in data]

fig = jgraph.draw(data , shader="lambert", default_node_color=0x383294, show_save=True)
# Out:
# <div id="graph-43b8f8a0-3de3-487d-8e47-5ac7051f9901"></div>
#            <script type="text/javascript">
#            require.config({baseUrl: '/',
#                              paths: {jgraph: ['nbextensions/jgraph.min', 'https://rawgit.com/patrickfuller/jgraph/master/js/build/jgraph.min']}});
#            require(['jgraph'], function () {
#                var $d = $('#graph-43b8f8a0-3de3-487d-8e47-5ac7051f9901');
#                $d.width(600); $d.height(400);
#                $d.jgraph = jQuery.extend({}, jgraph);
#                $d.jgraph.create($d, {nodeSize: 2.000000,
#                                      edgeSize: 0.250000,
#                                      defaultNodeColor: '0x383294',
#                                      defaultEdgeColor: '0xaaaaaa',
#                                      shader: 'lambert',
#                                      z: 100,
#                                      runOptimization: true,
#                                      directed: true,
#                                      showSave: true});
#                $d.jgraph.draw({
#     "edges": [
#         { "source": "circlebroke2", "target": "adviceanimals" },
#         { "source": "shitpost", "target": "adviceanimals" },
#         { "source": "bestof", "target": "adviceanimals" },
#         { "source": "subredditdrama", "target": "adviceanimals" },
#         { "source": "amrsucks", "target": "againstmensrights" },
#         { "source": "subredditdrama", "target": "anarchism" },
#         { "source": "drama", "target": "anarchism" },
#         { "source": "enoughlibertarianspam", "target": "anarcho_capitalism" },
#         { "source": "gaybroscirclejerk", "target": "askgaybros" },
#         { "source": "circlejerkaustralia", "target": "australia" },
#         { "source": "beercirclejerk", "target": "beer" },
#         { "source": "angryblackladies", "target": "blackladies" },
#         { "source": "bnestrong", "target": "brisbane" },
#         { "source": "subredditdrama", "target": "conspiracy" },
#         { "source": "drugscirclejerk", "target": "drugs" },
#         { "source": "frdbroke", "target": "femradebates" },
#         { "source": "circlebroke2", "target": "funny" },
#         { "source": "againstkarmawhores", "target": "funny" },
#         { "source": "subredditdrama", "target": "funny" },
#         { "source": "srssucks", "target": "gamerghazi" }
#     ],
#     "nodes": {
#         "adviceanimals": { "location": [ 2.0, 2.0, 2.0 ] },
#         "againstkarmawhores": { "location": [ 2.0, 2.0, 2.0 ] },
#         "againstmensrights": { "location": [ 2.0, 2.0, 2.0 ] },
#         "amrsucks": { "location": [ 2.0, 2.0, 2.0 ] },
#         "anarchism": { "location": [ 2.0, 2.0, 2.0 ] },
#         "anarcho_capitalism": { "location": [ -2.0, -2.0, -2.0 ] },
#         "angryblackladies": { "location": [ -2.0, -2.0, -2.0 ] },
#         "askgaybros": { "location": [ -2.0, -2.0, -2.0 ] },
#         "australia": { "location": [ -2.0, -2.0, -2.0 ] },
#         "beer": { "location": [ -2.0, -2.0, -2.0 ] },
#         "beercirclejerk": { "location": [ 2.0, 2.0, 2.0 ] },
#         "bestof": { "location": [ -2.0, -2.0, -2.0 ] },
#         "blackladies": { "location": [ 2.0, 2.0, 2.0 ] },
#         "bnestrong": { "location": [ -2.0, -2.0, -2.0 ] },
#         "brisbane": { "location": [ -2.0, -2.0, -2.0 ] },
#         "circlebroke2": { "location": [ 2.0, 2.0, 2.0 ] },
#         "circlejerkaustralia": { "location": [ -2.0, -2.0, -2.0 ] },
#         "conspiracy": { "location": [ -2.0, -2.0, -2.0 ] },
#         "drama": { "location": [ -2.0, -2.0, -2.0 ] },
#         "drugs": { "location": [ 2.0, 2.0, 2.0 ] },
#         "drugscirclejerk": { "location": [ -1.258226668635879, -1.1203254566784833, -0.8885398630078639 ] },
#         "enoughlibertarianspam": { "location": [ 1.5933069734280831, 2.0, 0.8745438634188035 ] },
#         "femradebates": { "location": [ 2.0, 2.0, 2.0 ] },
#         "frdbroke": { "location": [ 2.0, 2.0, 2.0 ] },
#         "funny": { "location": [ -1.1728423379108694, -0.5604384001929793, -1.652325483296729 ] },
#         "gamerghazi": { "location": [ 2.0, 2.0, 2.0 ] },
#         "gaybroscirclejerk": { "location": [ -2.0, -2.0, -2.0 ] },
#         "shitpost": { "location": [ 2.0, 2.0, 2.0 ] },
#         "srssucks": { "location": [ -0.11643802590485264, 0.16717581546536828, -0.3521870962167791 ] },
#         "subredditdrama": { "location": [ -2.0, -2.0, -2.0 ] }
#     }
# });
#
#                $d.resizable({
#                    aspectRatio: 600 / 400,
#                    resize: function (evt, ui) {
#                        $d.jgraph.renderer.setSize(ui.size.width,
#                                                   ui.size.height);
#                    }
#                });
#            });
#            </script>

# %%
data = graph.run("MATCH allShortestPaths((u:Subreddit {id:'mapporn'})-[*]-(me:Subreddit {id:'alpharetta'})) RETURN u.id, me.id")

data = [tuple(x) for x in data]

jgraph.draw(data , shader="lambert", default_node_color=0x383294)

# %% [markdown]
# #### Graph - python-igraph

# %%
from igraph import Graph as IGraph

query = '''
MATCH (c1:Subreddit)-[r:LINK]->(c2:Subreddit)
RETURN c1.id, c2.id, r.weight AS weight
'''

ig = IGraph.TupleList(graph.run(query), weights=True)

# %%
pg = ig.pagerank()
pgvs = []
for p in zip(ig.vs, pg):
    print(p)
    pgvs.append({"id": p[0]["name"], "pg": p[1]})
pgvs

write_clusters_query = '''
UNWIND {nodes} AS n
MATCH (c:Subreddit) WHERE c.id = n.id
SET c.pagerank = n.pg
'''

graph.run(write_clusters_query, nodes=pgvs)
# Out:
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 0, {'name': 'botsrights'}), 0.005629379427749086)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 1, {'name': '1200isjerky'}), 5.13627052488518e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 2, {'name': 'botrights'}), 0.000427717798411102)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 3, {'name': 'mylittleandysonic1'}), 0.00043314911202638586)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 4, {'name': '195'}), 7.457310872918094e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 5, {'name': 'ooer'}), 0.0002354988060110195)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 6, {'name': 'newscape'}), 4.254336239913031e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 7, {'name': '2007scape'}), 0.0005276823135513022)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 8, {'name': 'games'}), 0.0010504362623916625)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9, {'name': 'shitredditsays'}), 0.0039533401599505785)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 10, {'name': 'oppression'}), 0.0015868078162885903)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 11, {'name': 'drama'}), 0.010053050803993838)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 12, {'name': 'againstkarmawhores'}), 0.0012989186231604911)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 13, {'name': 'rsdarkscape'}), 7.058791787000322e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 14, {'name': 'runescape'}), 0.00036977594471573373)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 15, {'name': 'peoplewhosayheck'}), 0.0015500474384513544)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 16, {'name': 'circlebroke2'}), 0.004478068862015379)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 17, {'name': 'quityourbullshit'}), 0.0014305468993004403)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 18, {'name': 'shitamericanssay'}), 0.003601035715827917)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 19, {'name': 'bestof'}), 0.017377349118459645)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 20, {'name': 'shitpost'}), 0.004584297749742453)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 21, {'name': 'ice_poseidon'}), 8.60386826573078e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 22, {'name': 'bestofbanappeals'}), 2.8877729659635804e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 23, {'name': 'asablackman'}), 0.0016444382285986728)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 24, {'name': 'upvotedbecausegirl'}), 0.0004955986836334772)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>,
-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9109, {'name': 'slitherio'}), 2.6977457057169838e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9110, {'name': 'soccerstreams'}), 2.6977457057169838e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9111, {'name': 'wheeloftimerp'}), 3.67879446310559e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9112, {'name': 'rddt6'}), 4.9902376374038785e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9113, {'name': 'worldoftanksxbox'}), 4.9902376374038785e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9114, {'name': 'hotwifecaption'}), 5.7752816235359195e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9115, {'name': 'pcgamingtechsupport'}), 2.9403148674501434e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9116, {'name': 'wrestlingisreddit'}), 0.00010945709281972676)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9117, {'name': 'laboratorytuxedo'}), 0.00010945709281964314)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9118, {'name': 'garbagesociety'}), 2.8534483493920964e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9119, {'name': 'whatisthis'}), 2.8534483493920964e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9120, {'name': 'skylanders'}), 2.8324395021388777e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9121, {'name': 'environmental_science'}), 2.7574391366081765e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9122, {'name': 'newfoundland'}), 2.7574391366081765e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9123, {'name': 'wwi'}), 0.00010945709281972676)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9124, {'name': 'theoryofpropaganda'}), 0.00010945709281964314)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9125, {'name': 'uniformporn'}), 3.663067827823987e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9126, {'name': 'loaxbox'}), 2.9129235357226016e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9127, {'name': 'xpowers'}), 0.00010945709281972676)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9128, {'name': 'postworldpowers'}), 0.00010945709281964314)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9129, {'name': 'yanderesimulator'}), 0.00010945709281972676)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9130, {'name': 'yandere_simulator_'}), 0.00010945709281964314)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9131, {'name': 'yellowstone'}), 0.00010945709281972676)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9132, {'name': 'wildernessbackpacking'}), 0.00010945709281964314)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9133, {'name': 'songwriterscircle'}), 3.3059938849917436e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9134, {'name': 'gunporn'}), 2.7538134990023743e-05)
# (igraph.Vertex(<igraph.Graph object at 0x10b39b228>, 9135, {'name': 'motog'}), 2.7538134990023743e-05)

# %%
pageRank = '''
    MATCH (n:Subreddit)RETURN n.id AS name, n.pagerank AS pagerank ORDER BY pagerank DESC LIMIT 10
'''

x = graph.run(pageRank)

print(x.to_data_frame())
# Out:
#              name  pagerank
# 0  subredditdrama  0.027142
# 1          bestof  0.017377
# 2       askreddit  0.013125
# 3           drama  0.010053
# 4           funny  0.006496
# 5   todayilearned  0.005688
# 6      the_donald  0.005686
# 7      botsrights  0.005629
# 8            pics  0.005583
# 9       worldnews  0.005298

# %%
clusters = IGraph.community_walktrap(ig, weights="weight").as_clustering()

nodes = [{"id": node["name"]} for node in ig.vs]
for node in nodes:
    idx = ig.vs.find(name=node["id"]).index
    node["community"] = clusters.membership[idx]

write_clusters_query = '''
UNWIND {nodes} AS n
MATCH (c:Subreddit) WHERE c.id = n.id
SET c.community = toInt(n.community)
'''

graph.run(write_clusters_query, nodes=nodes)

# %%
community = '''
    MATCH (c:Subreddit) \
    WITH c.community AS cluster, collect(c.id) AS  members \
    RETURN cluster, members ORDER BY cluster ASC
'''

x2 = graph.run(community)

print(x2.to_data_frame())
# Out:
#       cluster                                            members
# 0           0  [18bfriendzonest, 1990boys, 19thworldproblems,...
# 1           1                                      [1200isjerky]
# 2           2                                        [botrights]
# 3           3                               [mylittleandysonic1]
# 4           4                                              [195]
# ...       ...                                                ...
# 6254     6254                                      [yellowstone]
# 6255     6255                            [wildernessbackpacking]
# 6256     6256                                [songwriterscircle]
# 6257     6257                                          [gunporn]
# 6258     6258                                            [motog]
#
# [6259 rows x 2 columns]
